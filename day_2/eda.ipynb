# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('train.csv')

# %%
print(df.info())


print(df.describe())


print(df.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
df.hist(bins=20, figsize=(15, 10))
plt.suptitle("Histograms of Numerical Features")
plt.show()

# %%
import math

numeric_cols = df.select_dtypes(include=np.number).columns
n = len(numeric_cols)

cols = 3
rows = 3

plt.figure(figsize=(15,12)) 

for i, col in enumerate(numeric_cols, 1): 
    plt.subplot(rows, cols, i)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# Pairplot
sns.pairplot(df[numeric_cols], corner=True)
plt.suptitle("Pairplot of Numerical Features", y=1.02)
plt.show()

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival Count by Gender")
plt.show()


sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title("Survival Count by Passenger Class")
plt.show()


sns.histplot(df['Age'].dropna(), kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# # inferences from the visualization
# * in correlation matrix we can see that fare and pclass has higher -ve correlation
# * also the survivals chances increases if you are in the 1st class.
# * females had greater chance of the survival
# * infants and todlers had greater chance of the survival as we have seen in the movies also
